# %%
import regex as re
with open('/root/autodl-tmp/Stanford-CS336-LanguageModeling/assignment1-basics/tests/fixtures/corpus.en', 'r', encoding='utf-8') as f:
    text = f.read()

PAT = r"""'(?:[sdmt]|ll|ve|re)| ?\p{L}+| ?\p{N}+| ?[^\s\p{L}\p{N}]+|\s+(?!\S)|\s+"""
